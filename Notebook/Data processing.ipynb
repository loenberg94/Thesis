# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from numpy import genfromtxt

# %%
thorup_real_world = genfromtxt('thorup_real_world_collected.csv', delimiter=',')
wulff_real_world = genfromtxt('wulff_real_world_collected.csv', delimiter=',')

thorup_complete = genfromtxt('thorup_complete_graph_collected.csv', delimiter=',')
thorup_dense = genfromtxt('thorup_dense_graph_collected.csv', delimiter=',')
thorup_semi_dense = genfromtxt('thorup_semi_dense_graph_collected.csv', delimiter=',')
thorup_sparse = genfromtxt('thorup_sparse_graph_collected.csv', delimiter=',')
thorup_very_sparse = genfromtxt('thorup_very_sparse_graph_collected.csv', delimiter=',')
thorup_super_dense = genfromtxt('thorup_super_dense_graph_collected.csv', delimiter=',')
thorup_very_dense = genfromtxt('thorup_very_dense_graph_collected.csv', delimiter=',')

wulff_complete = genfromtxt('wulff_complete_graph_collected.csv', delimiter=',')
wulff_dense = genfromtxt('wulff_dense_graph_collected.csv', delimiter=',')
wulff_semi_dense = genfromtxt('wulff_semi_dense_graph_collected.csv', delimiter=',')
wulff_sparse = genfromtxt('wulff_sparse_graph_collected.csv', delimiter=',')
wulff_very_sparse = genfromtxt('wulff_very_sparse_graph_collected.csv', delimiter=',')
wulff_super_dense = genfromtxt('wulff_super_dense_graph_collected.csv', delimiter=',')
wulff_very_dense = genfromtxt('wulff_very_dense_graph_collected.csv', delimiter=',')

# %%
real_world_k_values = [2, 3, 5, 8, 10, 13, 15, 18]
density_k_values = [2, 3, 5, 8, 10, 13]

# %%
# Thorup real world
t_r_max_qt = []
t_r_min_qt = []
t_r_avg_qt = []
t_r_max_stretch = []
t_r_min_stretch = []
t_r_avg_stretch = []

rd = []

for k in real_world_k_values:
    k_data = thorup_real_world[(k == thorup_real_world[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_r_min_qt.append(qt.min())
    t_r_max_qt.append(qt.max())
    t_r_avg_qt.append(qt.mean())
    t_r_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_r_avg_stretch.append(stretch.mean())
    
print(t_r_max_stretch)
print(t_r_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=real_world_k_values)
ax2.boxplot(rd, positions=real_world_k_values)

plt.show()
# Out:
# [2.812554, 2.998534, 3.745629, 4.668844, 5.100562, 4.361032, 4.31462, 4.809334]
# [1.0515583622500002, 1.1656102782999997, 1.2256058991750003, 1.2648566444, 1.265038387075, 1.2948397905250002, 1.2846172456499998, 1.308044655375]

# %%
plt.scatter(real_world_k_values, np.array(t_r_avg_stretch))
plt.xticks(real_world_k_values)
plt.show()

# %%
# Wulff-Nilsen real world
w_r_max_qt = []
w_r_min_qt = []
w_r_avg_qt = []
w_r_max_stretch = []
w_r_min_stretch = []
w_r_avg_stretch = []

rd = []

for k in real_world_k_values:
    k_data = wulff_real_world[(k == wulff_real_world[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_r_min_qt.append(qt.min())
    w_r_max_qt.append(qt.max())
    w_r_avg_qt.append(qt.mean())
    w_r_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_r_avg_stretch.append(stretch.mean())
    
print(w_r_max_stretch)
print(w_r_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=real_world_k_values)
ax2.boxplot(rd, positions=real_world_k_values)

plt.show()
# Out:
# [2.902498, 2.905238, 3.976505, 4.199534, 4.331527, 4.748387, 6.044341, 4.245058]
# [1.0563210046, 1.1417934141000001, 1.219259642475, 1.3266078809250001, 1.2679419584, 1.325891251125, 1.266876168375, 1.24500453215]

# %%
plt.scatter(real_world_k_values, np.array(w_r_avg_stretch))
plt.show()

# %%
plt.plot(real_world_k_values, t_r_avg_qt, label='ThorupZwick Avg')
#plt.scatter(real_world_k_values, t_r_max_qt, label='ThorupZwick Max')
plt.scatter(real_world_k_values, t_r_min_qt, label='ThorupZwick Min')
plt.plot(real_world_k_values, w_r_avg_qt, label='Wulff-Nilsen Avg')
#plt.scatter(real_world_k_values, w_r_max_qt, label='Wulff-Nilsen Max')
plt.scatter(real_world_k_values, w_r_min_qt, label='Wulff-Nilsen Min')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('K value')
plt.ylabel('Nanoseconds')
plt.xticks(real_world_k_values)
plt.show()

# %%
plt.plot(real_world_k_values, t_r_avg_stretch, label='ThorupZwick Avg')
#plt.scatter(real_world_k_values, t_r_max_stretch, label='ThorupZwick Max')
plt.plot(real_world_k_values, w_r_avg_stretch, label='Wulff-Nilsen Avg')
#plt.scatter(real_world_k_values, w_r_max_stretch, label='Wulff-Nilsen Max')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('K value')
plt.ylabel('Stretch')
plt.xticks(real_world_k_values)
plt.show()

# %%
# Thorup complete
t_c_max_qt = []
t_c_min_qt = []
t_c_avg_qt = []
t_c_max_stretch = []
t_c_min_stretch = []
t_c_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_complete[(k == thorup_complete[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_c_min_qt.append(qt.min())
    t_c_max_qt.append(qt.max())
    t_c_avg_qt.append(qt.mean())
    t_c_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_c_avg_stretch.append(stretch.mean())
    
print(t_c_max_stretch)
print(t_c_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 7.0, 8.0, 7.0]
# [1.5161867065999999, 1.6323583753000002, 1.7268033577, 1.8246666657000001, 1.8098416724000002, 1.7883300151000003]

# %%
# Wulff complete
w_c_max_qt = []
w_c_min_qt = []
w_c_avg_qt = []
w_c_max_stretch = []
w_c_min_stretch = []
w_c_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_complete[(k == wulff_complete[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_c_min_qt.append(qt.min())
    w_c_max_qt.append(qt.max())
    w_c_avg_qt.append(qt.mean())
    w_c_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_c_avg_stretch.append(stretch.mean())
    
print(w_c_max_stretch)
print(w_c_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 7.0, 7.0, 8.0]
# [1.5610367072, 1.6401317187, 1.7393533651000002, 1.7632116796000001, 1.8521349896, 1.8862883206999999]

# %%
# Thorup very sparse
t_vs_max_qt = []
t_vs_min_qt = []
t_vs_avg_qt = []
t_vs_max_stretch = []
t_vs_min_stretch = []
t_vs_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_very_sparse[(k == thorup_very_sparse[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_vs_min_qt.append(qt.min())
    t_vs_max_qt.append(qt.max())
    t_vs_avg_qt.append(qt.mean())
    t_vs_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_vs_avg_stretch.append(stretch.mean())
    
print(t_vs_max_stretch)
print(t_vs_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [2.899281, 3.912621, 4.647727, 5.0625, 5.03125, 5.382353]
# [1.3160690211000001, 1.3907864462000001, 1.4179292725, 1.4282492964000002, 1.3995892298, 1.4684737766000002]

# %%
# Wulff very sparse
w_vs_max_qt = []
w_vs_min_qt = []
w_vs_avg_qt = []
w_vs_max_stretch = []
w_vs_min_stretch = []
w_vs_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_very_sparse[(k == wulff_very_sparse[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_vs_min_qt.append(qt.min())
    w_vs_max_qt.append(qt.max())
    w_vs_avg_qt.append(qt.mean())
    w_vs_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_vs_avg_stretch.append(stretch.mean())
    
print(w_vs_max_stretch)
print(w_vs_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 3.775281, 4.806452, 4.301587, 4.87013, 4.47541]
# [1.3272056909999999, 1.4062817456, 1.4376795372, 1.43536942, 1.4114648616999999, 1.4679371737]

# %%
# Thorup semi dense
t_sd_max_qt = []
t_sd_min_qt = []
t_sd_avg_qt = []
t_sd_max_stretch = []
t_sd_min_stretch = []
t_sd_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_semi_dense[(k == thorup_semi_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_sd_min_qt.append(qt.min())
    t_sd_max_qt.append(qt.max())
    t_sd_avg_qt.append(qt.mean())
    t_sd_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_sd_avg_stretch.append(stretch.mean())
    
print(t_sd_max_stretch)
print(t_sd_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 5.0, 7.0, 5.5, 6.0]
# [1.4068004814, 1.5060347292999998, 1.5163682476999998, 1.5635402942, 1.5548190306, 1.5537870648]

# %%
# Wulff semi dense
w_sd_max_qt = []
w_sd_min_qt = []
w_sd_avg_qt = []
w_sd_max_stretch = []
w_sd_min_stretch = []
w_sd_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_semi_dense[(k == wulff_semi_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_sd_min_qt.append(qt.min())
    w_sd_max_qt.append(qt.max())
    w_sd_avg_qt.append(qt.mean())
    w_sd_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_sd_avg_stretch.append(stretch.mean())
    
print(w_sd_max_stretch)
print(w_sd_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 4.6, 5.5, 6.0, 5.166667, 5.8]
# [1.3973820175, 1.5127935347, 1.5333687935000002, 1.5618372571, 1.5419847175, 1.5954028457]

# %%
# Thorup dense
t_d_max_qt = []
t_d_min_qt = []
t_d_avg_qt = []
t_d_max_stretch = []
t_d_min_stretch = []
t_d_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_dense[(k == thorup_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_d_min_qt.append(qt.min())
    t_d_max_qt.append(qt.max())
    t_d_avg_qt.append(qt.mean())
    t_d_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_d_avg_stretch.append(stretch.mean())
    
print(t_d_max_stretch)
print(t_d_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 4.8, 5.0, 6.0, 4.833333, 6.5]
# [1.4105258619999999, 1.5397780412, 1.5553234462, 1.5905965184000002, 1.5938342316999998, 1.6100178545]

# %%
# Wulff dense
w_d_max_qt = []
w_d_min_qt = []
w_d_avg_qt = []
w_d_max_stretch = []
w_d_min_stretch = []
w_d_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_dense[(k == wulff_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_d_min_qt.append(qt.min())
    w_d_max_qt.append(qt.max())
    w_d_avg_qt.append(qt.mean())
    w_d_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_d_avg_stretch.append(stretch.mean())
    
print(w_d_max_stretch)
print(w_d_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 4.6, 5.0, 11.0, 8.0, 6.0]
# [1.4106874489, 1.5108822776000002, 1.5707003667000001, 1.5920256389999998, 1.6091645687, 1.6125733503]

# %%
# Thorup sparse
t_s_max_qt = []
t_s_min_qt = []
t_s_avg_qt = []
t_s_max_stretch = []
t_s_min_stretch = []
t_s_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_sparse[(k == thorup_sparse[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_s_min_qt.append(qt.min())
    t_s_max_qt.append(qt.max())
    t_s_avg_qt.append(qt.mean())
    t_s_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_s_avg_stretch.append(stretch.mean())
    
print(t_s_max_stretch)
print(t_s_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 4.214286, 4.818182, 6.636364, 5.444444, 5.75]
# [1.3754919096, 1.4404635336, 1.5038404978, 1.5494971365999999, 1.4841909663000001, 1.5256511298]

# %%
# Wulff sparse
w_s_max_qt = []
w_s_min_qt = []
w_s_avg_qt = []
w_s_max_stretch = []
w_s_min_stretch = []
w_s_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_sparse[(k == wulff_sparse[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_s_min_qt.append(qt.min())
    w_s_max_qt.append(qt.max())
    w_s_avg_qt.append(qt.mean())
    w_s_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_s_avg_stretch.append(stretch.mean())
    
print(w_s_max_stretch)
print(w_s_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 4.538462, 5.333333, 4.9375, 5.0, 6.454545]
# [1.3450378762, 1.4717097153000003, 1.4665800942000002, 1.5168647107000002, 1.5052332809, 1.5273504768]

# %%
# Thorup super dense
t_sud_max_qt = []
t_sud_min_qt = []
t_sud_avg_qt = []
t_sud_max_stretch = []
t_sud_min_stretch = []
t_sud_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_super_dense[(k == thorup_super_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_sud_min_qt.append(qt.min())
    t_sud_max_qt.append(qt.max())
    t_sud_avg_qt.append(qt.mean())
    t_sud_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_sud_avg_stretch.append(stretch.mean())
    
print(t_sud_max_stretch)
print(t_sud_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 7.0, 7.0, 7.0]
# [1.5379467142, 1.6352883707, 1.7349400195999998, 1.7824666697, 1.8179516655999999, 1.8627849886]

# %%
# Wulff super dense
w_sud_max_qt = []
w_sud_min_qt = []
w_sud_avg_qt = []
w_sud_max_stretch = []
w_sud_min_stretch = []
w_sud_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_super_dense[(k == wulff_super_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_sud_min_qt.append(qt.min())
    w_sud_max_qt.append(qt.max())
    w_sud_avg_qt.append(qt.mean())
    w_sud_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_sud_avg_stretch.append(stretch.mean())
    
print(w_sud_max_stretch)
print(w_sud_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 7.0, 7.0, 7.0]
# [1.531633376, 1.6563367062, 1.7466800212000002, 1.8080449954, 1.831743331, 1.8585783196]

# %%
# Thorup very dense
t_vd_max_qt = []
t_vd_min_qt = []
t_vd_avg_qt = []
t_vd_max_stretch = []
t_vd_min_stretch = []
t_vd_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = thorup_very_dense[(k == thorup_very_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    t_vd_min_qt.append(qt.min())
    t_vd_max_qt.append(qt.max())
    t_vd_avg_qt.append(qt.mean())
    t_vd_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    t_vd_avg_stretch.append(stretch.mean())
    
print(t_vd_max_stretch)
print(t_vd_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 8.0, 7.0, 8.0]
# [1.5432950374000003, 1.6290100231, 1.7328933438, 1.8107133242, 1.8218833233, 1.8614866503999998]

# %%
# Wulff very dense
w_vd_max_qt = []
w_vd_min_qt = []
w_vd_avg_qt = []
w_vd_max_stretch = []
w_vd_min_stretch = []
w_vd_avg_stretch = []

rd = []

for k in density_k_values:
    k_data = wulff_very_dense[(k == wulff_very_dense[:,2])]
    r, _ = k_data.shape
    qt = k_data[:,1]
    stretch = k_data[:,0]
    
    rd.append(stretch)
    
    w_vd_min_qt.append(qt.min())
    w_vd_max_qt.append(qt.max())
    w_vd_avg_qt.append(qt.mean())
    w_vd_max_stretch.append(stretch.max())
    #min_stretch.append(stretch.min)
    w_vd_avg_stretch.append(stretch.mean())
    
print(w_vd_max_stretch)
print(w_vd_avg_stretch)
    
fg1, ax1 = plt.subplots()
fg2, ax2 = plt.subplots()

ax1.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax2.set(
    xlabel='K value',
    ylabel='Stretch'
)

ax1.boxplot(rd, 0, '', positions=density_k_values)
ax2.boxplot(rd, positions=density_k_values)

plt.show()
# Out:
# [3.0, 5.0, 7.0, 7.0, 7.0, 7.0]
# [1.5251583711, 1.6407983656, 1.7382433444000003, 1.7777249942, 1.7628533378, 1.8149816585]

# %%
plt.scatter(density_k_values, w_c_avg_stretch, label="Wulff Complete")
plt.scatter(density_k_values, w_sud_avg_stretch, label="Wulff Super dense")
plt.scatter(density_k_values, w_vd_avg_stretch,label="Wulff Very dense")
plt.scatter(density_k_values, w_d_avg_stretch, label="Wulff Dense")
plt.scatter(density_k_values, w_sd_avg_stretch,label="Wulff Semi dense")
plt.scatter(density_k_values, w_s_avg_stretch, label="Wulff sparse")
plt.scatter(density_k_values, w_vs_avg_stretch,label="Wulff Very sparse")


plt.scatter(density_k_values, t_c_avg_stretch, label="ThorupZwick Complete")
plt.scatter(density_k_values, t_sud_avg_stretch, label="ThorupZwick Super dense")
plt.scatter(density_k_values, t_vd_avg_stretch,label="ThorupZwick Very dense")
plt.scatter(density_k_values, t_d_avg_stretch, label="ThorupZwick Dense")
plt.scatter(density_k_values, t_sd_avg_stretch,label="ThorupZwick Semi dense")
plt.scatter(density_k_values, t_s_avg_stretch, label="ThorupZwick Sparse")
plt.scatter(density_k_values, t_vs_avg_stretch,label="ThorupZwick Very sparse")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Stretch')
plt.xlabel('K value')
plt.xticks(density_k_values)
plt.show()

# %%
plt.plot(density_k_values, t_c_avg_stretch, label="ThorupZwick Complete")
plt.plot(density_k_values, t_sud_avg_stretch, label="ThorupZwick Super dense")
plt.plot(density_k_values, t_vd_avg_stretch,label="ThorupZwick Very dense")
plt.plot(density_k_values, t_d_avg_stretch, label="ThorupZwick Dense")
plt.plot(density_k_values, t_sd_avg_stretch,label="ThorupZwick Semi dense")
plt.plot(density_k_values, t_s_avg_stretch, label="ThorupZwick Sparse")
plt.plot(density_k_values, t_vs_avg_stretch,label="ThorupZwick Very sparse")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('Stretch')
plt.xlabel('K value')
plt.xticks(density_k_values)
plt.show()

# %%
plt.plot(density_k_values, w_c_avg_stretch, label="Wulff Complete")
plt.plot(density_k_values, w_sud_avg_stretch, label="Wulff Super dense")
plt.plot(density_k_values, w_vd_avg_stretch,label="Wulff Very dense")
plt.plot(density_k_values, w_d_avg_stretch, label="Wulff Dense")
plt.plot(density_k_values, w_sd_avg_stretch,label="Wulff Semi dense")
plt.plot(density_k_values, w_s_avg_stretch, label="Wulff sparse")
plt.plot(density_k_values, w_vs_avg_stretch,label="Wulff Very sparse")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(density_k_values)
plt.ylabel('Stretch')
plt.xlabel('K value')
plt.show()

# %%
complete_size_n = [1379041, 324078, 188814, 202234, 237426, 324059]
dense_size_n = [2108619   , 658259    , 397164    , 323397    , 344266   , 384130]
s_dense_size_n = [1918732   , 656206    , 335070    , 341253    , 345487    , 386057]
sparse_size_n = [1932037   , 652671    , 371831    , 324776    , 353688   , 404876]
v_sparse_size_n = [2028651   , 656411     , 378963    , 342028    , 345654    , 390126]
exp_size_n = [2000000, 646330, 315479, 252982, 251189, 264019]

plt.scatter(density_k_values, complete_size_n, label="Complete graph")
plt.scatter(density_k_values, dense_size_n, label="Dense graph")
plt.scatter(density_k_values, s_dense_size_n, label="Semi dense graph")
plt.scatter(density_k_values, sparse_size_n, label="Sparse graph")
plt.scatter(density_k_values, v_sparse_size_n, label="Very sparse graph")
plt.plot(density_k_values, exp_size_n, 'k-', label="Expected size")
#plt.yscale('log')
plt.xticks(density_k_values)
plt.ylabel('Size in n')
plt.xlabel('K value')
plt.legend()
plt.plot()
# Out:
# []

# %%
real_size_n = [269928894, 50054928, 17903018, 12386741, 12483275, 12897328, 13357269, 14202915]
exp_size_n = [271825000, 50896100, 16053800, 10070100, 9212770, 8978550, 9114700, 9520880]

plt.scatter(real_world_k_values, real_size_n, label="Real world graph")
plt.plot(real_world_k_values, exp_size_n, 'k-', label="Expected size")
plt.yscale('log')
plt.ylabel('Size in n')
plt.xlabel('K value')
plt.xticks(real_world_k_values)
plt.legend()
plt.show()
